# %% [markdown]
# Milestone 4 - Model Training
#
# Task 4: Based on the models you trained, iteratively train the model with different subsets of the data
#
# On many Data Science project, you will use Notebooks to, apart getting the clean data and training the model, explain the model and explain the results as if you were explaining it to a customer.

# %% [markdown]
# Import needed package and global value settings

# %%
import re
import pandas as pd
import os
import numpy as np
from csv import reader
import plotly.express as px
import missingno as msno
import pickle

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression

from sklearn.preprocessing import MinMaxScaler
from numpy import set_printoptions

from sklearn.preprocessing import StandardScaler

from sklearn.neighbors import KNeighborsClassifier

from sklearn.tree import DecisionTreeClassifier

from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier

pd.options.mode.chained_assignment = None

# %%
# READ IN cleaned_dataset.csv
full_pd = pd.read_csv("cleaned_dataset_b.csv")
full_pd
# Out:
#               League  Season  Round         Home_Team          Away_Team  \
# 0       championship    2021      4     Coventry City    AFC Bournemouth
# 1       championship    2021      4      Norwich City       Derby County
# 2       championship    2021      4  Blackburn Rovers       Cardiff City
# 3       championship    2021      4        Luton Town  Wycombe Wanderers
# 4       championship    2021      4     Middlesbrough           Barnsley
# ...              ...     ...    ...               ...                ...
# 111647       serie_b    1997     38           Pescara             Padova
# 111648       serie_b    1997     38             Genoa         Palermo FC
# 111649       serie_b    1997     38            Torino         Ravenna FC
# 111650       serie_b    1997     38       Salernitana            Reggina
# 111651       serie_b    1997     38           Brescia            Venezia
#
#         Elo_home  Elo_away  HOMETEAM_HOME_GOAL_SO_FAR  \
# 0           46.0      62.0                          3
# 1           62.0      60.0                          2
# 2           58.0      60.0                          5
# 3           51.0      41.0                          2
# 4           61.0      46.0                          1
# ...          ...       ...                        ...
# 111647      59.0      54.0                         32
# 111648      61.0      58.0                         33
# 111649      63.0      54.0                         27
# 111650      52.0      52.0                         20
# 111651      62.0      52.0                         24
#
#         HOMETEAM_AWAY_GOAL_SO_FAR  AWAYTEAM_HOME_GOAL_SO_FAR  \
# 0                               2                          4
# 1                               2                          0
# 2                               0                          1
# 3                               1                          0
# 4                               1                          0
# ...                           ...                        ...
# 111647                         15                         22
# 111648                         12                         24
# 111649                         23                         22
# 111650                          7                         23
# 111651                          8                         24
#
#         AWAYTEAM_AWAY_GOAL_SO_FAR  HOME_LASTEST_GOAL_DIFF  \
# 0                               2                       0
# 1                               6                       0
# 2                               4                       8
# 3                               3                       1
# 4                               1                      -1
# ...                           ...                     ...
# 111647                         15                       5
# 111648                         24                       2
# 111649                         18                      -2
# 111650                         18                      -2
# 111651                         13                       1
#
#         AWAY_LASTEST_GOAL_DIFF  Result
# 0                            2       0
# 1                           -7       0
# 2                           -1       0
# 3                           -8       1
# 4                           -3       1
# ...                        ...     ...
# 111647                      -3       0
# 111648                      -1       1
# 111649                      -2       0
# 111650                       3       0
# 111651                      -1       1
#
# [111652 rows x 14 columns]

# %%
# Create functions to filter different league
def getLeagueData(data, league, season=None):
    if season is None:
        league_pd =  data[(data["League"]==league)]
    else:
        league_pd =  data[(data["League"]==league) & (data["Season"]==season)]
    return league_pd

# %%
def get_ELO_diff(record):
    hscore = record['Elo_home']
    ascore = record['Elo_away']
    return (hscore - ascore)

# %%
def get_recent_goal_diff_diff(record):
    hscore = record['HOME_LASTEST_GOAL_DIFF']
    ascore = record['AWAY_LASTEST_GOAL_DIFF']
    return hscore - ascore

# %%
def get_home_away_total_goal_diff(record):
    hgoal = record['HOMETEAM_HOME_GOAL_SO_FAR']
    agoal = record['AWAYTEAM_AWAY_GOAL_SO_FAR']
    return hgoal - agoal

# %%
model_pd = getLeagueData(full_pd, "eerste_divisie")
model_pd
# Out:
# Empty DataFrame
# Columns: [League, Season, Round, Home_Team, Away_Team, Elo_home, Elo_away, HOMETEAM_HOME_GOAL_SO_FAR, HOMETEAM_AWAY_GOAL_SO_FAR, AWAYTEAM_HOME_GOAL_SO_FAR, AWAYTEAM_AWAY_GOAL_SO_FAR, HOME_LASTEST_GOAL_DIFF, AWAY_LASTEST_GOAL_DIFF, Result]
# Index: []

# %%
def tryModels(X, y):
    test_size = 0.3
    seed = 7
    X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=test_size, random_state=seed)

    # Model creation
    print("LogisticRegression")
    model = LogisticRegression() 
    model.fit(X_train, Y_train)
    result = model.score(X_train, Y_train) 
    print("Accuracy for train: %.3f%%" % (result*100.0))
    result = model.score(X_test, Y_test) 
    print("Accuracy for test: %.3f%%" % (result*100.0))
    print()

    # KNN 
    print("KNN")
    knn = KNeighborsClassifier(n_neighbors=15)
    knn.fit(X_train, Y_train)
    result = knn.score(X_train, Y_train) 
    print("Accuracy for train: %.3f%%" % (result*100.0))
    result = knn.score(X_test, Y_test) 
    print("Accuracy for test: %.3f%%" % (result*100.0))
    print()

    # decision trees  
    print("decision trees")
    clf = DecisionTreeClassifier()
    clf.fit(X_train, Y_train)
    result = clf.score(X_train, Y_train) 
    print("Accuracy for train: %.3f%%" % (result*100.0))
    result = clf.score(X_test, Y_test) 
    print("Accuracy for test: %.3f%%" % (result*100.0))
    print()

    # random forests
    print("random forests")
    model = RandomForestClassifier()
    model.fit(X_train, Y_train)
    result = model.score(X_train, Y_train) 
    print("Accuracy for train: %.3f%%" % (result*100.0))
    result = model.score(X_test, Y_test) 
    print("Accuracy for test: %.3f%%" % (result*100.0))
    print()

# %%
# load all directory as league name list
dir = "./Results"
leagues = [name for name in os.listdir(dir) if os.path.isdir(os.path.join(dir, name))]

# loop to open csv
result_with_goal_sofar_pd = pd.DataFrame()
for league in leagues:
    model_pd = getLeagueData(full_pd, league)
    model_pd = model_pd.dropna()

    if (model_pd.shape[0]==0):
        continue

    elo_diff_pd = model_pd.apply(get_ELO_diff, axis=1)
    model_pd.drop('Elo_home', inplace=True, axis=1)
    model_pd.drop('Elo_away', inplace=True, axis=1)
    model_pd.insert(loc=5, column="ELO_DIFF", value=elo_diff_pd.astype('Int64')) 
    
    recent_perf_diff_pd = model_pd.apply(get_recent_goal_diff_diff, axis=1)
    model_pd.drop('HOME_LASTEST_GOAL_DIFF', inplace=True, axis=1)
    model_pd.drop('AWAY_LASTEST_GOAL_DIFF', inplace=True, axis=1)
    model_pd.insert(loc=6, column="RECENT_PERF_DIFF", value=recent_perf_diff_pd.astype('Int64')) 

    goal_diff_pd = model_pd.apply(get_home_away_total_goal_diff, axis=1)
    model_pd.drop('HOMETEAM_HOME_GOAL_SO_FAR', inplace=True, axis=1)
    model_pd.drop('HOMETEAM_AWAY_GOAL_SO_FAR', inplace=True, axis=1)
    model_pd.drop('AWAYTEAM_HOME_GOAL_SO_FAR', inplace=True, axis=1)
    model_pd.drop('AWAYTEAM_AWAY_GOAL_SO_FAR', inplace=True, axis=1)
    model_pd.insert(loc=7, column="HOME_AWAY_GOAL_DIFF", value=recent_perf_diff_pd.astype('Int64')) 

    # delete no value column
    model_pd.drop('League', inplace=True, axis=1)
    model_pd.drop('Season', inplace=True, axis=1)
    model_pd.drop('Round', inplace=True, axis=1)
    model_pd.drop('Home_Team', inplace=True, axis=1)
    model_pd.drop('Away_Team', inplace=True, axis=1)

    array = model_pd.values
    X = array[:,0:(array.shape[1]-1)].astype('int')
    y = array[:,(array.shape[1]-1)].astype('int')

    # Scaler
    scaler = MinMaxScaler(feature_range=(0, 8))
    rescaledX = scaler.fit_transform(X)

    # summarize transformed data
    set_printoptions(precision=3)

    # Or Standardize
    #scaler = StandardScaler().fit(X)
    #rescaledX = scaler.transform(X)

    print()
    print()
    print(league)
    print("-------------------------------------")
    tryModels(rescaledX, y)
# Out:
# championship
# -------------------------------------
# LogisticRegression
# Accuracy for train: 56.667%
# Accuracy for test: 55.605%
#
# KNN
# Accuracy for train: 62.276%
# Accuracy for test: 52.167%
#
# decision trees
# Accuracy for train: 71.538%
# Accuracy for test: 51.420%
#
# random forests
# Accuracy for train: 71.538%
# Accuracy for test: 49.327%
#
#
#
# primeira_liga
# -------------------------------------
# LogisticRegression
# Accuracy for train: 63.976%
# Accuracy for test: 63.979%
#
# KNN
# Accuracy for train: 67.380%
# Accuracy for test: 60.622%
#
# decision trees
# Accuracy for train: 70.469%
# Accuracy for test: 57.839%
#
# random forests
# Accuracy for train: 70.469%
# Accuracy for test: 58.657%
#
#
#
# ligue_1
# -------------------------------------
# LogisticRegression
# Accuracy for train: 59.726%
# Accuracy for test: 59.981%
#
# KNN
# Accuracy for train: 62.519%
# Accuracy for test: 57.723%
#
# decision trees
# Accuracy for train: 66.252%
# Accuracy for test: 56.208%
#
# random forests
# Accuracy for train: 66.224%
# Accuracy for test: 55.950%
#
#
#
# segunda_division
# -------------------------------------
# LogisticRegression
# Accuracy for train: 56.377%
# Accuracy for test: 57.125%
#
# KNN
# Accuracy for train: 58.332%
# Accuracy for test: 53.460%
#
# decision trees
# Accuracy for train: 62.078%
# Accuracy for test: 54.869%
#
# random forests
# Accuracy for train: 62.056%
# Accuracy for test: 54.536%
#
#
#
# 2_liga
# -------------------------------------
# LogisticRegression
# Accuracy for train: 57.325%
# Accuracy for test: 56.816%
#
# KNN
# Accuracy for train: 62.411%
# Accuracy for test: 54.750%
#
# decision trees
# Accuracy for train: 66.838%
# Accuracy for test: 54.187%
#
# random forests
# Accuracy for train: 66.822%
# Accuracy for test: 53.924%
#
#
#
# serie_a
# -------------------------------------
# LogisticRegression
# Accuracy for train: 64.270%
# Accuracy for test: 63.238%
#
# KNN
# Accuracy for train: 66.650%
# Accuracy for test: 60.326%
#
# decision trees
# Accuracy for train: 69.895%
# Accuracy for test: 58.696%
#
# random forests
# Accuracy for train: 69.895%
# Accuracy for test: 59.356%
#
#
#
# bundesliga
# -------------------------------------
# LogisticRegression
# Accuracy for train: 60.166%
# Accuracy for test: 61.699%
#
# KNN
# Accuracy for train: 63.744%
# Accuracy for test: 58.271%
#
# decision trees
# Accuracy for train: 68.232%
# Accuracy for test: 55.402%
#
# random forests
# Accuracy for train: 68.232%
# Accuracy for test: 54.955%
#
#
#
# primera_division
# -------------------------------------
# LogisticRegression
# Accuracy for train: 61.307%
# Accuracy for test: 60.402%
#
# KNN
# Accuracy for train: 64.462%
# Accuracy for test: 58.688%
#
# decision trees
# Accuracy for train: 67.249%
# Accuracy for test: 56.176%
#
# random forests
# Accuracy for train: 67.249%
# Accuracy for test: 56.147%
#
#
#
# ligue_2
# -------------------------------------
# LogisticRegression
# Accuracy for train: 56.782%
# Accuracy for test: 57.017%
#
# KNN
# Accuracy for train: 60.839%
# Accuracy for test: 53.849%
#
# decision trees
# Accuracy for train: 64.208%
# Accuracy for test: 54.771%
#
# random forests
# Accuracy for train: 64.191%
# Accuracy for test: 54.531%
#
#
#
# premier_league
# -------------------------------------
# LogisticRegression
# Accuracy for train: 62.647%
# Accuracy for test: 62.785%
#
# KNN
# Accuracy for train: 64.949%
# Accuracy for test: 59.953%
#
# decision trees
# Accuracy for train: 67.901%
# Accuracy for test: 58.406%
#
# random forests
# Accuracy for train: 67.888%
# Accuracy for test: 58.085%
#
#
#
# eredivisie
# -------------------------------------
# LogisticRegression
# Accuracy for train: 66.198%
# Accuracy for test: 64.830%
#
# KNN
# Accuracy for train: 68.543%
# Accuracy for test: 62.016%
#
# decision trees
# Accuracy for train: 72.127%
# Accuracy for test: 58.812%
#
# random forests
# Accuracy for train: 72.111%
# Accuracy for test: 59.007%
#
#
#
# segunda_liga
# -------------------------------------
# LogisticRegression
# Accuracy for train: 94.702%
# Accuracy for test: 92.308%
#
# KNN
# Accuracy for train: 93.377%
# Accuracy for test: 90.769%
#
# decision trees
# Accuracy for train: 100.000%
# Accuracy for test: 95.385%
#
# random forests
# Accuracy for train: 100.000%
# Accuracy for test: 92.308%
#
#
#
# serie_b
# -------------------------------------
# LogisticRegression
# Accuracy for train: 57.626%
# Accuracy for test: 56.017%
#
# KNN
# Accuracy for train: 61.304%
# Accuracy for test: 53.157%
#
# decision trees
# Accuracy for train: 64.100%
# Accuracy for test: 53.401%
#
# random forests
# Accuracy for train: 64.085%
# Accuracy for test: 53.401%

# %%
# Save the model
from joblib import dump, load
dump(model, 'baseline_t2.joblib')
# Out:
# ['baseline_t2.joblib']

# %%
# Load the model
loaded_model = load('baseline.joblib')

# %% [markdown]
# take a look at the weights of your features and see which ones are important. Remove those that have low weights and check again the performance. Before you do that, you should check the performance of the model without feature selection on both training and testing sets, and observe if, by removing some features, the metrics on both sets get closer. Don't worry if you underfit right now, you will improve your model later.
